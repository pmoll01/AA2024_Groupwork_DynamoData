# %%
# import standard libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.rcParams['figure.figsize'] = (12, 10)
# supress versioning warnings of keras
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

import os
os.environ["KERAS_BACKEND"] = "torch"
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

charging_data = pd.read_pickle(os.path.join('Data', 'charging_data.pkl'))
weather_data = pd.read_pickle(os.path.join('Data', 'weather_data.pkl'))

agg_charging_data = pd.read_pickle(os.path.join('Data', 'aggregated_data.pkl'))
agg_charging_data['year'] = agg_charging_data.index.year

#print(agg_charging_data.head(), '\n Data Types: \n',agg_charging_data.dtypes )
print(agg_charging_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29717 entries, 2018-04-25 04:00:00-07:00 to 2021-09-14 08:00:00-07:00
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   activeSessions_site1     29717 non-null  int64
#  1   utilizationRate_site1    29717 non-null  float64
#  2   kWhDelivered_site1       29717 non-null  float64
#  3   idleRate_site1           29717 non-null  float64
#  4   blockedRate_site1        29717 non-null  float64
#  5   activeSessions_site2     29717 non-null  int64
#  6   utilizationRate_site2    29717 non-null  float64
#  7   kWhDelivered_site2       29717 non-null  float64
#  8   idleRate_site2           29717 non-null  float64
#  9   blockedRate_site2        29717 non-null  float64
#  10  activeSessions_total     29717 non-null  int64
#  11  kWhDelivered_total       29717 non-null  float64
#  12  utilizationRate_total    29717 non-null  float64
#  13  idleRate_total           29717 non-null  float64
#  14  blockedRate_total        29717 non-null  float64
#  15  temperature              23402 non-null  float64
#  16  cloud_cover              23402 non-null  float64
#  17  cloud_cover_description  23402 non-null  object
#  18  pressure                 23402 non-null  float64
#  19  windspeed                23402 non-null  float64
#  20  precipitation            23402 non-null  float64
#  21  hour_of_day              29717 non-null  int32
#  22  week_of_year             29717 non-null  UInt32
#  23  day_of_week              29717 non-null  int32
#  24  month_of_year            29717 non-null  int32
#  25  is_weekend               29717 non-null  bool
#  26  date                     29717 non-null  object
#  27  year                     29717 non-null  int32
# dtypes: UInt32(1), bool(1), float64(17), int32(4), int64(3), object(2)
# memory usage: 5.8+ MB
# None

# %%
# Load the pickled data
data = pd.read_pickle(os.path.join('Data', 'aggregated_data.pkl'))

# Select 'utilizationRate_total' column from the DataFrame
data = data[['utilizationRate_total']]  # This keeps it as a DataFrame, not a Series

data.index = pd.to_datetime(data.index)
data = data[data.index.year == 2021]

data.index.freq = 'H'

data['utilizationRate_total'].replace(0, np.nan, inplace=True)
data['utilizationRate_total'].fillna(method='bfill', inplace=True)
data['utilizationRate_total'].fillna(method='ffill', inplace=True)

# Now 'data' is a DataFrame, so you can work with it directly
print(data.head())
print(data['utilizationRate_total'].isna().sum())

# Plot the DataFrame
plt.figure(figsize=(18, 15))
plt.plot(data)
plt.title('Utilization Rate Over Time')
plt.xlabel('Time')
plt.ylabel('Utilization Rate')
plt.grid(True)
plt.show()
# Out:
#                            utilizationRate_total
# start_hour
# 2021-01-01 00:00:00-08:00               0.001986
# 2021-01-01 01:00:00-08:00               0.001986
# 2021-01-01 02:00:00-08:00               0.001986
# 2021-01-01 03:00:00-08:00               0.001986
# 2021-01-01 04:00:00-08:00               0.001986
# 0

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=168).mean()
    rolstd = timeseries.rolling(window=168).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:\n')
    dftest = adfuller(timeseries)
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
data = data[data['utilizationRate_total'] != 0]


data.columns = ['utilizationRate_total']
adfuller(data['utilizationRate_total'])
test_stationarity(data['utilizationRate_total'])
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                -9.708379e+00
# p-value                        1.027216e-16
# #Lags Used                     3.400000e+01
# Number of Observations Used    6.117000e+03
# Critical Value (1%)           -3.431419e+00
# Critical Value (5%)           -2.862013e+00
# Critical Value (10%)          -2.567022e+00
# dtype: float64

# %%
ts_log = np.log(data['utilizationRate_total'])

moving_avg = ts_log.rolling(12).mean()

ts_log_moving_avg_diff = ts_log - moving_avg

ts_log_moving_avg_diff.dropna(inplace=True)
test_stationarity(ts_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                -1.668497e+01
# p-value                        1.505278e-29
# #Lags Used                     3.400000e+01
# Number of Observations Used    6.106000e+03
# Critical Value (1%)           -3.431421e+00
# Critical Value (5%)           -2.862013e+00
# Critical Value (10%)          -2.567022e+00
# dtype: float64

# %%
expwighted_avg=ts_log.ewm(halflife = 12).mean() #Provides exponential weighted functions

ts_log_ewma_diff = ts_log - expwighted_avg
test_stationarity(ts_log_ewma_diff)
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                -1.334314e+01
# p-value                        5.865707e-25
# #Lags Used                     3.100000e+01
# Number of Observations Used    6.120000e+03
# Critical Value (1%)           -3.431419e+00
# Critical Value (5%)           -2.862012e+00
# Critical Value (10%)          -2.567021e+00
# dtype: float64

# %%
ts_log.shift(periods=1)
ts_log_diff = ts_log - ts_log.shift()
plt.plot(ts_log_diff)

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                  -19.067359
# p-value                           0.000000
# #Lags Used                       28.000000
# Number of Observations Used    6122.000000
# Critical Value (1%)              -3.431419
# Critical Value (5%)              -2.862012
# Critical Value (10%)             -2.567021
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(ts_log) #Seasonal decomposition using moving averages

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
ts_log_decompose = residual
ts_log_decompose.dropna(inplace=True)
test_stationarity(ts_log_decompose)
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                  -23.310245
# p-value                           0.000000
# #Lags Used                       34.000000
# Number of Observations Used    6093.000000
# Critical Value (1%)              -3.431424
# Critical Value (5%)              -2.862014
# Critical Value (10%)             -2.567023
# dtype: float64

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf
lag_acf = acf(ts_log_diff, nlags=20)
lag_pacf = pacf(ts_log_diff, nlags=20, method='ols')

#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(ts_log_decompose, order=(6, 1, 6), freq='H')  
results_ARIMA = model.fit()  
plt.plot(ts_log_decompose)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-ts_log_decompose)**2))
# Out:
# Text(0.5, 1.0, 'RSS: 1793.1927')

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)

predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()

predictions_ARIMA_log = pd.Series(0, index=ts_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
predictions_ARIMA_log = predictions_ARIMA_log.add(decomposition.trend, fill_value=0)
predictions_ARIMA_log = predictions_ARIMA_log.add(decomposition.seasonal, fill_value=0)

predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(data)
plt.plot(predictions_ARIMA)
plt.ylim(0, 0.5)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-data['utilizationRate_total'])**2)/len(data)))
# Out:
# Text(0.5, 1.0, 'RMSE: 1.6807')
